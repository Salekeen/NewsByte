# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from gensim.models import LdaModel
from gensim.corpora import Dictionary

import warnings
warnings.filterwarnings("ignore")
import pandas as pd

# %%
def preprocess (textstring):
    """A simple preprocess function that takes a textstring as input and then
    tokenize it using word_tokenizer,
    removes stopwords,
    lowercase each tokens,
    removes non-alphabatic characters
    """
    
    stops = set(stopwords.words("english"))
    tokens = word_tokenize(textstring)
    return [
        token.lower() for token in tokens
        if token.isalpha() and token not in stops
    ]

# %%
data_path = "../Get Data/Data/all_news/all_news_2022_10_09.csv"

# %%
df = pd.read_csv(data_path,encoding="utf-8")

# %%
df.head(5)
# Out:
#                                                 URLS  \
# 0  /news/bangladesh/crime-justice/news/bangladesh...
# 1  /sports/football/news/militao-takes-real-top-l...
# 2  /business/global-economy/news/india-kicks-bank...
# 3  /news/bangladesh/news/their-guardian-angel-313...
# 4  /news/bangladesh/accidents-fires/news/2-dead-w...
#
#                                             Headline  \
# 0  2 Bangladeshis killed by “BSF” along Satkhira,...
# 1  Militao takes Real top of La Liga, Atletico sc...
# 2                   India kicks off bank divestments
# 3                               Their guardian angel
# 4  2 dead while working inside septic tank in Cox...
#
#                                              Article
# 0  Two Bangladeshis have been shot dead along the...
# 1  Eder Militao's early goal earned Real Madrid a...
# 2  The Indian government is looking to sell a 60....
# 3  Setara was a playful child, curious about the ...
# 4  Two construction workers have died and another...

# %%
type(df['Article'])
# Out:
# pandas.core.series.Series

# %%
articles = []
for article in df['Article']:
    articles.append(preprocess(article))

# %%
articles[0]
# Out:
# ['two',
#  'bangladeshis',
#  'shot',
#  'dead',
#  'along',
#  'border',
#  'india',
#  'satkhira',
#  'satkhira',
#  'bangladeshi',
#  'shot',
#  'dead',
#  'india',
#  'border',
#  'security',
#  'force',
#  'along',
#  'kaliani',
#  'border',
#  'sadar',
#  'upazila',
#  'today',
#  'october',
#  'family',
#  'however',
#  'denied',
#  'firing',
#  'taken',
#  'place',
#  'around',
#  'reports',
#  'local',
#  'deceased',
#  'identified',
#  'abu',
#  'hasan',
#  'dakshin',
#  'kushkhali',
#  'village',
#  'sadar',
#  'father',
#  'haider',
#  'ali',
#  'sheikh',
#  'said',
#  'my',
#  'son',
#  'crossed',
#  'border',
#  'went',
#  'india',
#  'last',
#  'night',
#  'bsf',
#  'personnel',
#  'dubli',
#  'camp',
#  'india',
#  'basirhat',
#  'opposite',
#  'kaliani',
#  'border',
#  'fired',
#  'later',
#  'someone',
#  'brought',
#  'bangladesh',
#  'territory',
#  'admitted',
#  'satkhira',
#  'sadar',
#  'hospital',
#  'around',
#  'bgb',
#  'commander',
#  'lt',
#  'col',
#  'mohammad',
#  'al',
#  'mahmud',
#  'said',
#  'when',
#  'bsf',
#  'asked',
#  'hasan',
#  'death',
#  'denied',
#  'firing',
#  'however',
#  'letter',
#  'flag',
#  'meeting',
#  'sent',
#  'battalion',
#  'level',
#  'in',
#  'chuadanga',
#  'body',
#  'bangladeshi',
#  'man',
#  'seen',
#  'lying',
#  'indian',
#  'side',
#  'border',
#  'the',
#  'bsf',
#  'took',
#  'away',
#  'body',
#  'around',
#  'pm',
#  'chairman',
#  'union',
#  'parishad',
#  'sam',
#  'zakaria',
#  'alam',
#  'darshana',
#  'police',
#  'station',
#  'ahm',
#  'lutful',
#  'kabir',
#  'said',
#  'body',
#  'belonged',
#  'muntaj',
#  'choto',
#  'baldia',
#  'village',
#  'union',
#  'damurhuda',
#  'upazila',
#  'contacted',
#  'zakaria',
#  'said',
#  'victim',
#  'family',
#  'told',
#  'muntaz',
#  'gone',
#  'indian',
#  'border',
#  'last',
#  'night',
#  'bring',
#  'cows',
#  'illegally',
#  'this',
#  'morning',
#  'locals',
#  'found',
#  'body',
#  'lying',
#  'inside',
#  'indian',
#  'said',
#  'muntaz',
#  'associates',
#  'given',
#  'information',
#  'killed',
#  'bsf',
#  'firing',
#  'look',
#  'away',
#  'body',
#  'bgb',
#  'director',
#  'lt',
#  'col',
#  'shah',
#  'ishtiaq',
#  'said',
#  'came',
#  'know',
#  'death',
#  'bgb',
#  'investigating',
#  'the',
#  'officer',
#  'confirmed',
#  'sending',
#  'letter',
#  'bsf',
#  'it',
#  'take',
#  'time',
#  'said']

# %%
# Create a dictionary representation of the articles
dictionary = Dictionary(articles)

# %%
# Filtering infrequent of too frequent words
dictionary.filter_extremes(no_below=10,no_above=0.5)

# %%
len(dictionary)
# Out:
# 257

# %%
corpus = [
    dictionary.doc2bow(article)
    for article in articles
]

# %%
len(corpus)
# Out:
# 110

# %%
dictionary[0]
# Out:
# 'al'

# %%
# Making an index to word-dictionary
temp = dictionary[0]
id2word = dictionary.id2token

# %%
id2word
# Out:
# {0: 'al',
#  1: 'along',
#  2: 'around',
#  3: 'asked',
#  4: 'bangladesh',
#  5: 'came',
#  6: 'death',
#  7: 'director',
#  8: 'family',
#  9: 'force',
#  10: 'found',
#  11: 'given',
#  12: 'hasan',
#  13: 'hospital',
#  14: 'however',
#  15: 'identified',
#  16: 'in',
#  17: 'information',
#  18: 'it',
#  19: 'killed',
#  20: 'know',
#  21: 'last',
#  22: 'later',
#  23: 'local',
#  24: 'look',
#  25: 'man',
#  26: 'meeting',
#  27: 'night',
#  28: 'october',
#  29: 'officer',
#  30: 'place',
#  31: 'police',
#  32: 'reports',
#  33: 'security',
#  34: 'seen',
#  35: 'sheikh',
#  36: 'side',
#  37: 'station',
#  38: 'take',
#  39: 'taken',
#  40: 'this',
#  41: 'time',
#  42: 'today',
#  43: 'told',
#  44: 'took',
#  45: 'two',
#  46: 'union',
#  47: 'upazila',
#  48: 'went',
#  49: 'when',
#  50: 'able',
#  51: 'area',
#  52: 'back',
#  53: 'could',
#  54: 'early',
#  55: 'find',
#  56: 'first',
#  57: 'following',
#  58: 'friday',
#  59: 'get',
#  60: 'half',
#  61: 'help',
#  62: 'higher',
#  63: 'home',
#  64: 'lead',
#  65: 'league',
#  66: 'long',
#  67: 'make',
#  68: 'new',
#  69: 'next',
#  70: 'one',
#  71: 'role',
#  72: 'saturday',
#  73: 'second',
#  74: 'since',
#  75: 'started',
#  76: 'team',
#  77: 'three',
#  78: 'top',
#  79: 'us',
#  80: 'way',
#  81: 'we',
#  82: 'without',
#  83: 'work',
#  84: 'working',
#  85: 'according',
#  86: 'also',
#  87: 'bank',
#  88: 'better',
#  89: 'case',
#  90: 'cent',
#  91: 'central',
#  92: 'even',
#  93: 'five',
#  94: 'foreign',
#  95: 'government',
#  96: 'health',
#  97: 'including',
#  98: 'least',
#  99: 'made',
#  100: 'may',
#  101: 'minister',
#  102: 'months',
#  103: 'much',
#  104: 'part',
#  105: 'per',
#  106: 'process',
#  107: 'public',
#  108: 'set',
#  109: 'several',
#  110: 'total',
#  111: 'year',
#  112: 'years',
#  113: 'after',
#  114: 'among',
#  115: 'and',
#  116: 'but',
#  117: 'daily',
#  118: 'day',
#  119: 'development',
#  120: 'every',
#  121: 'go',
#  122: 'great',
#  123: 'group',
#  124: 'head',
#  125: 'hossain',
#  126: 'i',
#  127: 'important',
#  128: 'islam',
#  129: 'like',
#  130: 'many',
#  131: 'money',
#  132: 'office',
#  133: 'official',
#  134: 'often',
#  135: 'others',
#  136: 'people',
#  137: 'rahman',
#  138: 'showed',
#  139: 'social',
#  140: 'star',
#  141: 'still',
#  142: 'they',
#  143: 'treatment',
#  144: 'trying',
#  145: 'used',
#  146: 'well',
#  147: 'world',
#  148: 'another',
#  149: 'died',
#  150: 'due',
#  151: 'lack',
#  152: 'added',
#  153: 'already',
#  154: 'department',
#  155: 'different',
#  156: 'month',
#  157: 'power',
#  158: 'september',
#  159: 'start',
#  160: 'taking',
#  161: 'a',
#  162: 'demand',
#  163: 'economy',
#  164: 'global',
#  165: 'major',
#  166: 'managing',
#  167: 'million',
#  168: 'present',
#  169: 'price',
#  170: 'prices',
#  171: 'country',
#  172: 'general',
#  173: 'led',
#  174: 'making',
#  175: 'never',
#  176: 'prime',
#  177: 'road',
#  178: 'see',
#  179: 'statement',
#  180: 'would',
#  181: 'yesterday',
#  182: 'countries',
#  183: 'dhaka',
#  184: 'international',
#  185: 'press',
#  186: 'support',
#  187: 'four',
#  188: 'changes',
#  189: 'face',
#  190: 'high',
#  191: 'hours',
#  192: 'late',
#  193: 'must',
#  194: 'need',
#  195: 'nine',
#  196: 'result',
#  197: 'right',
#  198: 'think',
#  199: 'within',
#  200: 'change',
#  201: 'chief',
#  202: 'data',
#  203: 'good',
#  204: 'increase',
#  205: 'lost',
#  206: 'rate',
#  207: 'senior',
#  208: 'behind',
#  209: 'tk',
#  210: 'across',
#  211: 'cases',
#  212: 'number',
#  213: 'percent',
#  214: 'accused',
#  215: 'current',
#  216: 'leader',
#  217: 'sector',
#  218: 'state',
#  219: 'city',
#  220: 'event',
#  221: 'increased',
#  222: 'industry',
#  223: 'national',
#  224: 'pandemic',
#  225: 'report',
#  226: 'getting',
#  227: 'going',
#  228: 'key',
#  229: 'less',
#  230: 'officials',
#  231: 'six',
#  232: 'come',
#  233: 'days',
#  234: 'he',
#  235: 'members',
#  236: 'seven',
#  237: 'future',
#  238: 'main',
#  239: 'ministry',
#  240: 'president',
#  241: 'special',
#  242: 'university',
#  243: 'likely',
#  244: 'week',
#  245: 'filed',
#  246: 'although',
#  247: 'as',
#  248: 'recent',
#  249: 'released',
#  250: 'using',
#  251: 'towards',
#  252: 'human',
#  253: 'importance',
#  254: 'say',
#  255: 'despite',
#  256: 'business'}

# %%
# train the topic model
model = LdaModel(
    corpus=corpus,
    id2word=id2word,
    iterations=400,
    num_topics=10
)

# %%
model.top_topics(corpus)
# Out:
# [([(0.03558791, 'league'),
#    (0.028100094, 'two'),
#    (0.025031075, 'would'),
#    (0.019448943, 'i'),
#    (0.018942153, 'tk'),
#    (0.01517504, 'also'),
#    (0.014437637, 'hours'),
#    (0.014376664, 'it'),
#    (0.014376618, 'us'),
#    (0.014315946, 'bangladesh'),
#    (0.013572684, 'business'),
#    (0.0135447495, 'time'),
#    (0.013164731, 'president'),
#    (0.012915394, 'group'),
#    (0.012266346, 'set'),
#    (0.012019671, 'last'),
#    (0.011745663, 'dhaka'),
#    (0.011476818, 'new'),
#    (0.011154065, 'around'),
#    (0.011049236, 'and')],
#   -1.5231625177414636),
#  ([(0.028470874, 'hospital'),
#    (0.020639904, 'tk'),
#    (0.019282253, 'also'),
#    (0.01741522, 'bangladesh'),
#    (0.0149968695, 'two'),
#    (0.014333311, 'three'),
#    (0.013461171, 'new'),
#    (0.013460116, 'we'),
#    (0.013292181, 'dhaka'),
#    (0.012827906, 'percent'),
#    (0.012531609, 'i'),
#    (0.012504477, 'last'),
#    (0.011914824, 'day'),
#    (0.011141631, 'process'),
#    (0.011085078, 'around'),
#    (0.010525288, 'health'),
#    (0.00991102, 'due'),
#    (0.009615176, 'total'),
#    (0.009596492, 'time'),
#    (0.009313485, 'years')],
#   -1.533253879239459),
#  ([(0.05036755, 'hospital'),
#    (0.02408538, 'also'),
#    (0.016419481, 'one'),
#    (0.015865179, 'it'),
#    (0.015824502, 'time'),
#    (0.015790217, 'treatment'),
#    (0.015496503, 'day'),
#    (0.014980127, 'process'),
#    (0.014693893, 'three'),
#    (0.013727149, 'may'),
#    (0.013510828, 'year'),
#    (0.013497874, 'added'),
#    (0.012740933, 'last'),
#    (0.012570359, 'get'),
#    (0.012186704, 'tk'),
#    (0.0121033145, 'we'),
#    (0.011438815, 'daily'),
#    (0.011432283, 'this'),
#    (0.011344757, 'according'),
#    (0.01133491, 'within')],
#   -1.6160056244832504),
#  ([(0.03394298, 'i'),
#    (0.031085562, 'officials'),
#    (0.020517426, 'people'),
#    (0.018188944, 'also'),
#    (0.017166562, 'meeting'),
#    (0.016726207, 'government'),
#    (0.015716918, 'tk'),
#    (0.015619895, 'many'),
#    (0.015242067, 'day'),
#    (0.014642594, 'one'),
#    (0.012975856, 'bangladesh'),
#    (0.012841196, 'home'),
#    (0.012084283, 'we'),
#    (0.011263555, 'total'),
#    (0.010980364, 'they'),
#    (0.010980297, 'yesterday'),
#    (0.010980275, 'per'),
#    (0.010683814, 'would'),
#    (0.010001996, 'around'),
#    (0.009613588, 'dhaka')],
#   -1.6227761662932754),
#  ([(0.021807708, 'bangladesh'),
#    (0.018552754, 'home'),
#    (0.018552745, 'us'),
#    (0.016382795, 'cent'),
#    (0.01638267, 'also'),
#    (0.016382543, 'per'),
#    (0.01529795, 'year'),
#    (0.015297927, 'world'),
#    (0.015297582, 'people'),
#    (0.014212741, 'new'),
#    (0.013127886, 'september'),
#    (0.012042858, 'major'),
#    (0.010958006, 'take'),
#    (0.010957832, 'demand'),
#    (0.009873207, 'rahman'),
#    (0.009873179, 'million'),
#    (0.009873151, 'president'),
#    (0.00987313, 'change'),
#    (0.0098731015, 'in'),
#    (0.009873063, 'first')],
#   -1.7189950980645274),
#  ([(0.030552587, 'recent'),
#    (0.0257181, 'star'),
#    (0.021208532, 'million'),
#    (0.019305931, 'yesterday'),
#    (0.018889412, 'also'),
#    (0.018521596, 'two'),
#    (0.018145686, 'power'),
#    (0.0150116, 'friday'),
#    (0.014916352, 'official'),
#    (0.0145381, 'demand'),
#    (0.01439521, 'daily'),
#    (0.014278589, 'day'),
#    (0.014258951, 'us'),
#    (0.014249245, 'one'),
#    (0.013719136, 'people'),
#    (0.012860455, 'released'),
#    (0.012410665, 'would'),
#    (0.012397883, 'country'),
#    (0.01196607, 'many'),
#    (0.011897235, 'percent')],
#   -1.7622752695972173),
#  ([(0.032267097, 'bangladesh'),
#    (0.027556721, 'year'),
#    (0.025405444, 'bank'),
#    (0.020742895, 'last'),
#    (0.01856253, 'also'),
#    (0.016612444, 'we'),
#    (0.016358996, 'business'),
#    (0.01607636, 'people'),
#    (0.015585678, 'per'),
#    (0.0148762865, 'cent'),
#    (0.014457854, 'power'),
#    (0.013153964, 'global'),
#    (0.013059826, 'development'),
#    (0.011787037, 'month'),
#    (0.011017943, 'industry'),
#    (0.010659494, 'day'),
#    (0.010567105, 'higher'),
#    (0.010464084, 'country'),
#    (0.0104450295, 'rate'),
#    (0.010439073, 'director')],
#   -1.8182069683248656),
#  ([(0.025123661, 'per'),
#    (0.022909861, 'bangladesh'),
#    (0.022709455, 'also'),
#    (0.020855943, 'bank'),
#    (0.019651081, 'us'),
#    (0.018860325, 'cent'),
#    (0.014295272, 'world'),
#    (0.014057776, 'people'),
#    (0.013676436, 'government'),
#    (0.013662491, 'one'),
#    (0.013041171, 'million'),
#    (0.01288492, 'would'),
#    (0.012513846, 'police'),
#    (0.010595933, 'i'),
#    (0.00979619, 'last'),
#    (0.009410757, 'report'),
#    (0.009407582, 'time'),
#    (0.0092093125, 'minister'),
#    (0.009140562, 'year'),
#    (0.009131266, 'many')],
#   -1.8550744413251132),
#  ([(0.03336328, 'we'),
#    (0.030357743, 'bangladesh'),
#    (0.01833485, 'industry'),
#    (0.018334333, 'would'),
#    (0.01532922, 'government'),
#    (0.015328993, 'take'),
#    (0.015328929, 'like'),
#    (0.01532891, 'league'),
#    (0.015328589, 'also'),
#    (0.012323394, 'first'),
#    (0.012323328, 'chief'),
#    (0.0123233115, 'two'),
#    (0.012323265, 'event'),
#    (0.0123232, 'one'),
#    (0.01232319, 'team'),
#    (0.0123231625, 'members'),
#    (0.009317798, 'police'),
#    (0.009317749, 'president'),
#    (0.009317744, 'many'),
#    (0.009317721, 'per')],
#   -1.9175864994351854),
#  ([(0.033728678, 'bangladesh'),
#    (0.023344425, 'police'),
#    (0.01948505, 'state'),
#    (0.019178668, 'us'),
#    (0.016752118, 'i'),
#    (0.015605718, 'people'),
#    (0.01471371, 'we'),
#    (0.014558791, 'one'),
#    (0.014161092, 'two'),
#    (0.013044552, 'around'),
#    (0.013026463, 'killed'),
#    (0.012981233, 'three'),
#    (0.0118251145, 'team'),
#    (0.011736803, 'security'),
#    (0.011476869, 'first'),
#    (0.011283424, 'years'),
#    (0.011141792, 'also'),
#    (0.010446929, 'station'),
#    (0.010446917, 'minister'),
#    (0.010370775, 'it')],
#   -2.0285068766387897)]
